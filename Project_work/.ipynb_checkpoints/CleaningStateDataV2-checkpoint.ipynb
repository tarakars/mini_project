# %%
import csv
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
City_data_2013 = 'C:/Users/kouam/mini_project/Project_work/Raw_Data_State/State_data_2013.xlsx'
City_data_2014 = 'C:/Users/kouam/mini_project/Project_work/Raw_Data_State/State_data_2014.xlsx'
City_data_2015=  'C:/Users/kouam/mini_project/Project_work/Raw_Data_State/State_data_2015.xlsx'
City_data_2016 = 'C:/Users/kouam/mini_project/Project_work/Raw_Data_State/State_data_2016.xlsx'
City_data_2017 = 'C:/Users/kouam/mini_project/Project_work/Raw_Data_State/State_data_2017.xlsx'

# %%
City_2013_df = pd.read_excel(City_data_2013)
City_2014_df = pd.read_excel(City_data_2014)
City_2015_df = pd.read_excel(City_data_2015)
City_2016_df = pd.read_excel(City_data_2016)
City_2017_df = pd.read_excel(City_data_2017)

# %%
# City_2013_copy_df = City_2013_df.dropna(axis=1, how='all')
# City_2014_copy_df = City_2014_df.dropna(axis=1, how='all')
# City_2015_copy_df = City_2015_df.dropna(axis=1, how='all')
# City_2016_copy_df = City_2016_df.dropna(axis=1, how='all')
# City_2017_copy_df = City_2017_df.dropna(axis=1, how='all')

# %%
City_2013_copy_df = City_2013_df
City_2014_copy_df = City_2014_df
City_2015_copy_df = City_2015_df
City_2016_copy_df = City_2016_df
City_2017_copy_df = City_2017_df

# %%
City_2013_copy_df.fillna(0)
City_2014_copy_df.fillna(0)
City_2015_copy_df.fillna(0)
City_2016_copy_df.fillna(0)
City_2017_copy_df.fillna(0)
# Out:
#     PRIM_STATE   AREA                                          AREA_NAME  \
# 0           AK  11260                                      Anchorage, AK
# 1           AK  11260                                      Anchorage, AK
# 2           AK  11260                                      Anchorage, AK
# 3           AK  11260                                      Anchorage, AK
# 4           AK  11260                                      Anchorage, AK
# 5           AK  11260                                      Anchorage, AK
# 6           AK  11260                                      Anchorage, AK
# 7           AK  21820                                      Fairbanks, AK
# 8           AK  21820                                      Fairbanks, AK
# 9           AK  21820                                      Fairbanks, AK
# 10          AK  21820                                      Fairbanks, AK
# 11          AL  11500                   Anniston-Oxford-Jacksonville, AL
# ...

# %%
City_2013_copy_df['Year'] = '2013'
City_2014_copy_df['Year'] = '2014'
City_2015_copy_df['Year'] = '2015'
City_2016_copy_df['Year'] = '2016'
City_2017_copy_df['Year'] = '2017'

# %%
City_2013_copy_df.fillna(0)
City_2014_copy_df.fillna(0)
City_2015_copy_df.fillna(0)
City_2015_copy_df.fillna(0)
City_2017_copy_df.fillna(0)
# Out:
#     PRIM_STATE   AREA                                          AREA_NAME  \
# 0           AK  11260                                      Anchorage, AK
# 1           AK  11260                                      Anchorage, AK
# 2           AK  11260                                      Anchorage, AK
# 3           AK  11260                                      Anchorage, AK
# 4           AK  11260                                      Anchorage, AK
# 5           AK  11260                                      Anchorage, AK
# 6           AK  11260                                      Anchorage, AK
# 7           AK  21820                                      Fairbanks, AK
# 8           AK  21820                                      Fairbanks, AK
# 9           AK  21820                                      Fairbanks, AK
# 10          AK  21820                                      Fairbanks, AK
# 11          AL  11500                   Anniston-Oxford-Jacksonville, AL
# ...

# %%
City_2013_copy_df.replace(['#', '*','**'],[0.0, 0.0,0.0]) 
City_2014_copy_df.replace(['#', '*','**'],[0.0, 0.0,0.0])
City_2015_copy_df.replace(['#', '*','**'],[0.0, 0.0,0.0]) 
City_2016_copy_df.replace(['#', '*','**'],[0.0, 0.0,0.0]) 
City_2017_copy_df.replace(['#', '*','**'],[0.0, 0.0,0.0])
# Out:
#     PRIM_STATE   AREA                                          AREA_NAME  \
# 0           AK  11260                                      Anchorage, AK
# 1           AK  11260                                      Anchorage, AK
# 2           AK  11260                                      Anchorage, AK
# 3           AK  11260                                      Anchorage, AK
# 4           AK  11260                                      Anchorage, AK
# 5           AK  11260                                      Anchorage, AK
# 6           AK  11260                                      Anchorage, AK
# 7           AK  21820                                      Fairbanks, AK
# 8           AK  21820                                      Fairbanks, AK
# 9           AK  21820                                      Fairbanks, AK
# 10          AK  21820                                      Fairbanks, AK
# 11          AL  11500                   Anniston-Oxford-Jacksonville, AL
# ...

# %%
columns = ['ANNUAL', 'HOURLY']
City_2013_copy_df.drop(columns, inplace=True, axis=1)
City_2014_copy_df.drop(columns, inplace=True, axis=1)
City_2015_copy_df.drop(columns, inplace=True, axis=1)
City_2016_copy_df.drop(columns, inplace=True, axis=1)
City_2017_copy_df.drop(columns, inplace=True, axis=1)
City_2013_copy_df
# Out:
#      PRIM_STATE   AREA                           AREA_NAME OCC_CODE  \
# 0            AK  11260                       Anchorage, AK  13-1111
# 1            AK  11260                       Anchorage, AK  13-1161
# 2            AK  11260                       Anchorage, AK  13-2031
# 3            AK  11260                       Anchorage, AK  13-2051
# 4            AK  11260                       Anchorage, AK  15-1121
# 5            AK  11260                       Anchorage, AK  15-2031
# 6            AK  21820                       Fairbanks, AK  13-1111
# 7            AK  21820                       Fairbanks, AK  13-1161
# 8            AK  21820                       Fairbanks, AK  13-2031
# 9            AK  21820                       Fairbanks, AK  15-2031
# 10           AL  11500                 Anniston-Oxford, AL  13-1111
# 11           AL  12220                  Auburn-Opelika, AL  13-1161
# 12           AL  13820               Birmingham-Hoover, AL  13-1111
# ...

# %%
City_2013_copy_df.columns
City_2013_copy_df.set_index('AREA_NAME')
# Out:
#                                    PRIM_STATE   AREA OCC_CODE  \
# AREA_NAME
# Anchorage, AK                              AK  11260  13-1111
# Anchorage, AK                              AK  11260  13-1161
# Anchorage, AK                              AK  11260  13-2031
# Anchorage, AK                              AK  11260  13-2051
# Anchorage, AK                              AK  11260  15-1121
# Anchorage, AK                              AK  11260  15-2031
# Fairbanks, AK                              AK  21820  13-1111
# Fairbanks, AK                              AK  21820  13-1161
# Fairbanks, AK                              AK  21820  13-2031
# Fairbanks, AK                              AK  21820  15-2031
# Anniston-Oxford, AL                        AL  11500  13-1111
# Auburn-Opelika, AL                         AL  12220  13-1161
# Birmingham-Hoover, AL                      AL  13820  13-1111
# Birmingham-Hoover, AL                      AL  13820  13-1161
# ...

# %%
#tot_city_emp_2017 = City_2017_copy_df.groupby(["AREA_NAME","Year"], as_index=False)["TOT_EMP"].sum()
#tot_city_emp_2016 = City_2016_copy_df.groupby(["AREA_NAME","Year"], as_index=False)["TOT_EMP"].sum()
#tot_city_emp_2015 = City_2015_copy_df.groupby(["AREA_NAME","Year"], as_index=False)["TOT_EMP"].sum()
#tot_city_emp_2014 = City_2014_copy_df.groupby(["AREA_NAME","Year"], as_index=False)["TOT_EMP"].sum()
#tot_city_emp_2013 = City_2013_copy_df.groupby(["AREA_NAME"], as_index=False)["TOT_EMP"].sum()

#tot_city_emp_2013 = pd.DataFrame({'Tot_Employments':City_2013_copy_df.groupby(['AREA_NAME','Year'])['TOT_EMP'].sum()}).reset_index()


#total_city_emp_year = [tot_city_emp_2013]
#total_city_emp_year = [tot_city_emp_2017,tot_city_emp_2016,tot_city_emp_2015,tot_city_emp_2014,tot_city_emp_2013]
#total_city_emp_year

# %%
# pd.options.display.float_format = '{:.2f}'.format
# df_2013 = pd.DataFrame(total_city_emp_year, columns = ["AREA_NAME", "TOT_EMP"])

# df_2013

# %%
pd.options.display.float_format = '{:.2f}'.format
City_2013_copy_df['TOT_EMP'] = pd.to_numeric(City_2013_copy_df['TOT_EMP'],errors='coerce')
City_2013_copy_df2 = pd.DataFrame(City_2013_copy_df.groupby("AREA_NAME")["TOT_EMP"].sum())
# City_2013_copy_df2.reset_index()
# City_2013_copy_df2.index

# %%
# City_2013_copy_df['H_MEAN'] = pd.to_numeric(City_2013_copy_df['H_MEAN'],errors='coerce')
# City_2013_copy_df3 = pd.DataFrame(City_2013_copy_df.groupby("AREA_NAME")["H_MEAN"].mean())

# City_2013_copy_df['A_MEAN'] = pd.to_numeric(City_2013_copy_df['A_MEAN'],errors='coerce')
# City_2013_copy_df4 = pd.DataFrame(City_2013_copy_df.groupby("AREA_NAME")["A_MEAN"].mean())

# City_2013_copy_df['H_PCT10'] = pd.to_numeric(City_2013_copy_df['H_PCT10'],errors='coerce')
# City_2013_copy_df5 = pd.DataFrame(City_2013_copy_df.groupby("AREA_NAME")["H_PCT10"].mean())

# City_2013_copy_df['H_PCT25'] = pd.to_numeric(City_2013_copy_df['H_PCT25'],errors='coerce')
# City_2013_copy_df6 = pd.DataFrame(City_2013_copy_df.groupby("AREA_NAME")["H_PCT25"].mean())

# City_2013_copy_df['H_PCT75'] = pd.to_numeric(City_2013_copy_df['H_PCT75'],errors='coerce')
# City_2013_copy_df7 = pd.DataFrame(City_2013_copy_df.groupby("AREA_NAME")["H_PCT75"].mean())

# City_2013_copy_df['H_PCT90'] = pd.to_numeric(City_2013_copy_df['H_PCT90'],errors='coerce')
# City_2013_copy_df8 = pd.DataFrame(City_2013_copy_df.groupby("AREA_NAME")["H_PCT90"].mean())

# City_2013_copy_df['A_PCT10'] = pd.to_numeric(City_2013_copy_df['A_PCT10'],errors='coerce')
# City_2013_copy_df9 = pd.DataFrame(City_2013_copy_df.groupby("AREA_NAME")["A_PCT10"].mean())

# City_2013_copy_df['A_PCT25'] = pd.to_numeric(City_2013_copy_df['A_PCT25'],errors='coerce')
# City_2013_copy_df10 = pd.DataFrame(City_2013_copy_df.groupby("AREA_NAME")["A_PCT25"].mean())

# City_2013_copy_df['A_PCT75'] = pd.to_numeric(City_2013_copy_df['H_PCT75'],errors='coerce')
# City_2013_copy_df11 = pd.DataFrame(City_2013_copy_df.groupby("AREA_NAME")["A_PCT75"].mean())

# City_2013_copy_df['A_PCT90'] = pd.to_numeric(City_2013_copy_df['A_PCT90'],errors='coerce')
# City_2013_copy_df12 = pd.DataFrame(City_2013_copy_df.groupby("AREA_NAME")["A_PCT90"].mean())
# # City_2013_copy_df3.reset_index()
# # City_2013_copy_df3.index

# %%
# Merge the two DataFrames together based on the city they share
# City_df = pd.merge(City_2013_copy_df2, City_2013_copy_df3, on='AREA_NAME')
# City_df.head()

# %%
# City_2013_copy_df2.merge(City_2013_copy_df3,on='AREA_NAME').merge(City_2013_copy_df4,on='AREA_NAME')

# %%
#master_df['tot_emp_2013'] = City_2013_copy_df['TOT_EMP'].groupby('AREA_NAME').sum()

City_2014_copy_df['TOT_EMP'] = pd.to_numeric(City_2014_copy_df['TOT_EMP'],errors='coerce')

City_2015_copy_df['TOT_EMP'] = pd.to_numeric(City_2015_copy_df['TOT_EMP'],errors='coerce')

City_2016_copy_df['TOT_EMP'] = pd.to_numeric(City_2016_copy_df['TOT_EMP'],errors='coerce')

City_2017_copy_df['TOT_EMP'] = pd.to_numeric(City_2017_copy_df['TOT_EMP'],errors='coerce')
master_df = pd.DataFrame()
master_df['Tot_Emp_2013'] = City_2013_copy_df.groupby("AREA_NAME")["TOT_EMP"].sum()
master_df['Tot_Emp_2014'] = City_2014_copy_df.groupby("AREA_NAME")["TOT_EMP"].sum()
master_df['Tot_Emp_2015'] = City_2015_copy_df.groupby("AREA_NAME")["TOT_EMP"].sum()
master_df['Tot_Emp_2016'] = City_2016_copy_df.groupby("AREA_NAME")["TOT_EMP"].sum()
master_df['Tot_Emp_2017'] = City_2017_copy_df.groupby("AREA_NAME")["TOT_EMP"].sum()
#master_df['tot_emp_2014'] = df_2014['tot_emp'].sum()
master_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ebbd065e850c> in <module>()
#       1 #master_df['tot_emp_2013'] = City_2013_copy_df['TOT_EMP'].groupby('AREA_NAME').sum()
#       2
# ----> 3 City_2014_copy_df['TOT_EMP'] = pd.to_numeric(City_2014_copy_df['TOT_EMP'],errors='coerce')
#       4
#       5 City_2015_copy_df['TOT_EMP'] = pd.to_numeric(City_2015_copy_df['TOT_EMP'],errors='coerce')
#
# NameError: name 'pd' is not defined

# %%
test = pd.DataFrame(City_2014_copy_df.groupby("AREA_NAME")["TOT_EMP"].sum())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-3e86c0c5f40d> in <module>()
# ----> 1 test = pd.DataFrame(City_2014_copy_df.groupby("AREA_NAME")["TOT_EMP"].sum())
#
# NameError: name 'pd' is not defined
